# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 動画名変更とフォルダの移動

# %%
import os
root_dir = "/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/mmaction_video"
move_names = os.listdir(root_dir)
for move_name in move_names:
    move_dir = os.path.join(root_dir, move_name)
    for file in os.listdir(move_dir):
      direction_dir = os.path.join(root_dir, move_name, file)
      for video_name in os.listdir(direction_dir):
        video_path = os.path.join(root_dir, move_name, file, video_name)
        os. rename(video_path, video_path[:-6])

# %%
import shutil
root_dir = "/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/mmaction_video"
shutil.copytree(root_dir, "/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/データ/mmaction_exe", dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/データ/mmaction_exe'

# %% [markdown]
# 動画名ごとにpickleファイルをcopyする

# %%
import os
import shutil
root_dir = "/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/データ/mmaction_exe"
move_names = os.listdir(root_dir)
for move_name in move_names:
    move_dir = os.path.join(root_dir, move_name)
    for direction_name in os.listdir(move_dir):
      direction_dir = os.path.join(root_dir, move_name, direction_name)
      for video_name in os.listdir(direction_dir):
        video_name_path = os.path.join(root_dir, move_name, direction_name, video_name)
        for pickle_name in os.listdir("/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/データ/mmaction_exe_default"):

          video_name_path.split("/")[-1].split(".")[0]
          print(pickle_name)
        # shutil.copy(video_name_path.split(".")[0] + ".pkl", "/content/drive/MyDrive/Colab Notebooks/2023年度スポコン/データ/mmaction
      # for video_name in os.listdir(direction_dir):
      #   video_path = os.path.join(root_dir, move_name, file_name, video_name)
# Out:
# ntu_pose_extraction.py
# .ipynb_checkpoints
# train_anno
# val_anno
# video_full
# test_anno
# loops.py
# analyze_logs.py
# last_checkpoint
# eval
# test_pred.csv
# video
# empty
# models
# zyudou_custom_data.pkl
# train_val_loss1118.png
# train_loss1118.csv
# val_loss1118.csv
# val_loss.csv
# train_val_loss.png
# gameover_anno
# test_labels_based_pklfile.csv
# test_pred1.csv
# slowonly_r50_8xb16-u48-240e_ntu60-xsub-keypoint.py
# train_loss.csv
# zyudou_custom_data1.pkl
# rtmw-x_8xb320-270e_cocktail13-384x288.py
# yokoshiho_anno
# ntu_pose_extraction.py
# .ipynb_checkpoints
# train_anno
# val_anno
# video_full
# test_anno
# loops.py
# analyze_logs.py
# last_checkpoint
# eval
# test_pred.csv
# video
# empty
# models
# zyudou_custom_data.pkl
# train_val_loss1118.png
# train_loss1118.csv
# val_loss1118.csv
# val_loss.csv
# train_val_loss.png
# gameover_anno
# test_labels_based_pklfile.csv
# test_pred1.csv
# slowonly_r50_8xb16-u48-240e_ntu60-xsub-keypoint.py
# train_loss.csv
# ...
